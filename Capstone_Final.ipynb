# %%
import pandas as pd
from sklearn.impute import KNNImputer

# %%
df = pd.read_csv("/content/train.csv")
df_test = pd.read_csv("/content/test.csv")
df.columns, df.shape, df_test.shape
# Out:
# (Index(['ID', 'Company', 'Quarter', 'QuickRatio', 'InventoryRatio',
#         'RevenueGrowth', 'MarketshareChange', 'Bond rating', 'Stock rating',
#         'Region', 'Industry', 'Sales'],
#        dtype='object'),
#  (675, 12),
#  (150, 11))

# %%
df.describe()
# Out:
#                ID  QuickRatio  InventoryRatio  RevenueGrowth  \
# count  675.000000  675.000000      523.000000     675.000000
# mean   394.555556    1.603867        4.265124      -0.009733
# std    204.960069    0.595615        3.108644       0.067390
# min      0.000000    0.500000        1.260000      -0.200000
# 25%    216.500000    0.990000        2.630000      -0.070000
# 50%    433.000000    1.730000        3.420000       0.000000
# 75%    579.000000    2.155000        4.725000       0.050000
# max    674.000000    2.490000       24.840000       0.080000
#
#        MarketshareChange         Sales
# count         675.000000    525.000000
# mean           -0.002904   3556.708571
# std             0.017622   2028.059368
# min            -0.050000    864.000000
# 25%            -0.015000   1992.000000
# 50%             0.000000   3007.000000
# 75%             0.010000   4523.000000
# max             0.020000  11686.000000

# %%
df = df[['Company','QuickRatio', 'InventoryRatio',
        'RevenueGrowth', 'MarketshareChange', 'Bond rating', 'Stock rating',
        'Region', 'Industry', 'Sales']]

# %%
df_test = df_test[['Company', 'QuickRatio', 'InventoryRatio',
        'RevenueGrowth', 'MarketshareChange', 'Bond rating', 'Stock rating',
        'Region', 'Industry']]

# %%
df.head()
# Out:
#   Company  QuickRatio  InventoryRatio  RevenueGrowth  MarketshareChange  \
# 0   CMP01        2.02            7.71           0.05              -0.04
# 1   CMP01        2.01            4.10           0.03               0.00
# 2   CMP01        2.02            6.79           0.06              -0.02
# 3   CMP01        1.98            3.97           0.01               0.02
# 4   CMP01        1.96            7.41          -0.07               0.02
#
#   Bond rating Stock rating Region           Industry   Sales
# 0         CCC          Buy  South  Metal Fabrication  1517.0
# 1         CCC         Hold  South  Metal Fabrication  2968.0
# 2         CCC          Buy  South  Metal Fabrication  1497.0
# 3         CCC          Buy  South  Metal Fabrication  2929.0
# 4         CCC          Buy  South  Metal Fabrication  1452.0

# %%
from sklearn.preprocessing import OneHotEncoder
columns=['Company','Bond rating', 'Stock rating', 'Region', 'Industry']

encoder = OneHotEncoder(handle_unknown="ignore", sparse = False)


encoded_data = encoder.fit_transform(df[columns])


df_encoded = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(columns))


X_encoded = pd.concat([df.drop(columns=columns), df_encoded], axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
data_test = df_test[columns]

# %%
test_encoded = encoder.transform(data_test)

# %%
test_encoded_df = pd.DataFrame(test_encoded, columns=encoder.get_feature_names_out(columns))

# %%
test_df = pd.concat([df_test.drop(columns=columns), test_encoded_df], axis=1)

# %%
X_encoded.shape
# Out:
# (675, 99)

# %%
X_encoded.isnull().sum()
# Out:
# QuickRatio                      0
# InventoryRatio                152
# RevenueGrowth                   0
# MarketshareChange               0
# Sales                         150
#                              ...
# Region_South                    0
# Region_West                     0
# Industry_Automobile             0
# Industry_Infrastructure         0
# Industry_Metal Fabrication      0
# Length: 99, dtype: int64

# %%
imputer = KNNImputer(n_neighbors=3)
df_encoded_clean = imputer.fit_transform(X_encoded)
X_imputed_df = pd.DataFrame(df_encoded_clean, columns=X_encoded.columns)

# %%
df_test_encoded_clean = imputer.fit_transform(test_df)

X_imputed_df_test = pd.DataFrame(df_test_encoded_clean, columns=test_df.columns)

# %%
X_imputed_df.isnull().sum(), X_imputed_df.shape
# Out:
# (QuickRatio                    0
#  InventoryRatio                0
#  RevenueGrowth                 0
#  MarketshareChange             0
#  Sales                         0
#                               ..
#  Region_South                  0
#  Region_West                   0
#  Industry_Automobile           0
#  Industry_Infrastructure       0
#  Industry_Metal Fabrication    0
#  Length: 99, dtype: int64,
#  (675, 99))

# %%
X_imputed_df_test.isnull().sum(), X_imputed_df_test.shape
# Out:
# (QuickRatio                    0
#  InventoryRatio                0
#  RevenueGrowth                 0
#  MarketshareChange             0
#  Company_CMP01                 0
#                               ..
#  Region_South                  0
#  Region_West                   0
#  Industry_Automobile           0
#  Industry_Infrastructure       0
#  Industry_Metal Fabrication    0
#  Length: 98, dtype: int64,
#  (150, 98))

# %%
Y = X_imputed_df['Sales']
X = X_imputed_df.drop(columns=['Sales'])

import numpy as np
X = np.asarray(X).astype(np.float32)
Y = np.asarray(Y).astype(np.float32)

# %%
Y.shape, X.shape
# Out:
# ((675,), (675, 98))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from keras import backend as K

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))

model = Sequential()
model.add(Dense(98, input_shape=(98,), activation='relu', kernel_regularizer='l2'))
model.add(Dense(60, activation='relu', kernel_regularizer='l2'))
model.add(Dense(20, activation='relu', kernel_regularizer='l2'))
model.add(Dense(1))

opt = tf.keras.optimizers.Adam(lr=0.01)
model.compile(loss=root_mean_squared_error, optimizer=opt)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
from keras.callbacks import EarlyStopping
early_stopping_monitor = EarlyStopping(monitor='val_loss', patience=10)
model.fit(x=X, y=Y, validation_split = 0.1, batch_size=2, epochs=100, callbacks = [early_stopping_monitor])
# Out:
# Epoch 1/100
# 304/304 [==============================] - 2s 3ms/step - loss: 2553.3914 - val_loss: 1888.9270
# Epoch 2/100
# 304/304 [==============================] - 1s 2ms/step - loss: 1606.1318 - val_loss: 1662.3242
# Epoch 3/100
# 304/304 [==============================] - 2s 5ms/step - loss: 1439.1770 - val_loss: 1487.0420
# Epoch 4/100
# 304/304 [==============================] - 2s 6ms/step - loss: 1289.4478 - val_loss: 1557.7411
# Epoch 5/100
# 304/304 [==============================] - 1s 4ms/step - loss: 1202.8901 - val_loss: 1463.9690
# Epoch 6/100
# 304/304 [==============================] - 1s 3ms/step - loss: 1132.6957 - val_loss: 1467.1703
# Epoch 7/100
# 304/304 [==============================] - 1s 2ms/step - loss: 1071.0337 - val_loss: 1277.0394
# Epoch 8/100
# 304/304 [==============================] - 1s 2ms/step - loss: 1013.3480 - val_loss: 1188.7114
# Epoch 9/100
# 304/304 [==============================] - 1s 2ms/step - loss: 954.1181 - val_loss: 1188.5409
# Epoch 10/100
# 304/304 [==============================] - 1s 2ms/step - loss: 915.3331 - val_loss: 1041.4086
# Epoch 11/100
# 304/304 [==============================] - 1s 2ms/step - loss: 867.7062 - val_loss: 897.2443
# Epoch 12/100
# 304/304 [==============================] - 1s 2ms/step - loss: 830.6107 - val_loss: 753.5630
# Epoch 13/100
# 304/304 [==============================] - 1s 2ms/step - loss: 800.6899 - val_loss: 726.2174
# Epoch 14/100
# 304/304 [==============================] - 1s 2ms/step - loss: 774.9418 - val_loss: 708.6552
# Epoch 15/100
# 304/304 [==============================] - 1s 2ms/step - loss: 753.8780 - val_loss: 608.3475
# Epoch 16/100
# 304/304 [==============================] - 1s 2ms/step - loss: 734.0443 - val_loss: 626.2281
# Epoch 17/100
# 304/304 [==============================] - 1s 2ms/step - loss: 715.5674 - val_loss: 555.1899
# Epoch 18/100
# 304/304 [==============================] - 1s 2ms/step - loss: 699.9924 - val_loss: 636.6384
# Epoch 19/100
# 304/304 [==============================] - 1s 2ms/step - loss: 683.8436 - val_loss: 555.4930
# Epoch 20/100
# 304/304 [==============================] - 1s 2ms/step - loss: 674.0488 - val_loss: 530.6386
# Epoch 21/100
# 304/304 [==============================] - 1s 3ms/step - loss: 664.5955 - val_loss: 579.4597
# Epoch 22/100
# 304/304 [==============================] - 1s 3ms/step - loss: 660.9574 - val_loss: 560.6453
# Epoch 23/100
# 304/304 [==============================] - 1s 3ms/step - loss: 650.0836 - val_loss: 596.1068
# Epoch 24/100
# 304/304 [==============================] - 1s 3ms/step - loss: 645.1224 - val_loss: 600.4761
# Epoch 25/100
# 304/304 [==============================] - 1s 2ms/step - loss: 639.1103 - val_loss: 569.6064
# Epoch 26/100
# 304/304 [==============================] - 1s 2ms/step - loss: 639.3916 - val_loss: 593.4167
# Epoch 27/100
# 304/304 [==============================] - 1s 2ms/step - loss: 640.9733 - val_loss: 606.8925
# Epoch 28/100
# 304/304 [==============================] - 1s 2ms/step - loss: 633.7534 - val_loss: 590.5610
# Epoch 29/100
# 304/304 [==============================] - 1s 2ms/step - loss: 636.2901 - val_loss: 586.3394
# Epoch 30/100
# 304/304 [==============================] - 1s 2ms/step - loss: 627.1257 - val_loss: 611.4781

# %%
test_predictions = model.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(Y_test, test_predictions)
print("Mean Absolute Error (MAE) on the testing set:", mae)
# Out:
# Mean Absolute Error (MAE) on the testing set: 553.74664

# %%
train_predictions = model.predict(X_train)

mae_train = mean_absolute_error(Y_train, train_predictions)
print("Mean Absolute Error (MAE) on the training set:", mae_train)
# Out:
# 17/17 [==============================] - 0s 2ms/step
# Mean Absolute Error (MAE) on the training set: 616.35345

# %%
predictions = model.predict(X_imputed_df_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
predictions = pd.DataFrame(predictions,columns=["Sales"])
result = pd.concat([df_test["ID"],predictions],axis=1)
result.to_csv("DL-6.csv",index=False)

# %%
submission = pd.read_csv("DL-6.csv")
submission
# Out:
#       ID      Sales
# 0      7  2813.6704
# 1      8  2354.6934
# 2     16  4526.0690
# 3     17  3829.7537
# 4     25  5985.7856
# ..   ...        ...
# 145  656  5636.7266
# 146  664  2913.5935
# 147  665  3215.0542
# 148  673  1847.7676
# 149  674  1958.3455
#
# [150 rows x 2 columns]
